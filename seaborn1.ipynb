# %%
#python library for visualisation==>seaborn
import seaborn as sns
df=sns.load_dataset('tips')  #tips is a preloaded dataset of seaborn
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
df.tail()
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2

# %%
df.dtypes
# Out:
# total_bill     float64
# tip            float64
# sex           category
# smoker        category
# day           category
# time          category
# size             int64
# dtype: object

# %%
#feature selection
#2 types :  correlation  and   ki square test

#1 correlation

# relationship between 2 numerical column
# it shows how one column is related to other column
# +1 to -1
# positive correlation : one value increases,other also increases
# negative correlation:one value increases,other decreases
# No correlation : no relationship between the variables

# %%
#checking correlation

correlation=df.corr(numeric_only=True)
correlation
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
#1 heatmap
sns.heatmap(correlation,cmap="coolwarm") #cmap="coolwarm"
# if correleatioon increases it has bright colour
# Out:
# <Axes: >

# %%
#2 jointplot :numerical relation
sns.jointplot(x='total_bill',y='tip',data=df,kind="hex")  #kind='hex or'reg'

# %%
#3 pairplot : numerical variable relations (multiple)
sns.pairplot(df,hue='sex')

# %%
df['smoker'].value_counts()
# Out:
# smoker
# No     151
# Yes     93
# Name: count, dtype: int64

# %%
#4 countplot
# only for categorical column
sns.countplot(x='sex',data=df)
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
#5 barplot

sns.barplot(x='total_bill',y='day',data=df)

#if the length of the earror bar(black line ) increases variation increases
# Out:
# <Axes: xlabel='total_bill', ylabel='day'>

# %%
#6 box plot
# used to find the outliers
#Q1===>25th percentile
#Q2===.Median
#Q3===>75th percentile
#whiskers===> line extending from the box
# upper whisker===> maximum value
#lower whisker===> minimum value

sns.boxplot(x='smoker',y='total_bill' ,data=df)
# Out:
# <Axes: xlabel='smoker', ylabel='total_bill'>

# %%
df['total_bill'].unique()
# Out:
# array([16.99, 10.34, 21.01, 23.68, 24.59, 25.29,  8.77, 26.88, 15.04,
#        14.78, 10.27, 35.26, 15.42, 18.43, 14.83, 21.58, 10.33, 16.29,
#        16.97, 20.65, 17.92, 20.29, 15.77, 39.42, 19.82, 17.81, 13.37,
#        12.69, 21.7 , 19.65,  9.55, 18.35, 15.06, 20.69, 17.78, 24.06,
#        16.31, 16.93, 18.69, 31.27, 16.04, 17.46, 13.94,  9.68, 30.4 ,
#        18.29, 22.23, 32.4 , 28.55, 18.04, 12.54, 10.29, 34.81,  9.94,
#        25.56, 19.49, 38.01, 26.41, 11.24, 48.27, 13.81, 11.02, 17.59,
#        20.08, 16.45,  3.07, 20.23, 15.01, 12.02, 17.07, 26.86, 25.28,
#        14.73, 10.51, 27.2 , 22.76, 17.29, 19.44, 16.66, 10.07, 32.68,
#        15.98, 34.83, 13.03, 18.28, 24.71, 21.16, 28.97, 22.49,  5.75,
#        16.32, 22.75, 40.17, 27.28, 12.03, 12.46, 11.35, 15.38, 44.3 ,
#        22.42, 20.92, 15.36, 20.49, 25.21, 18.24, 14.31, 14.  ,  7.25,
#        38.07, 23.95, 25.71, 17.31, 29.93, 10.65, 12.43, 24.08, 11.69,
# ...

# %%
sns.boxplot(y='total_bill',data=df)
# Out:
# <Axes: ylabel='total_bill'>

# %%
sns.boxplot(y='tip',data=df)
# Out:
# <Axes: ylabel='tip'>

# %%
df.dtypes
# Out:
# total_bill     float64
# tip            float64
# sex           category
# smoker        category
# day           category
# time          category
# size             int64
# dtype: object

# %%
df.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')

# %%
#multiple category visualisation using boxplot

sns.boxplot(x='time',y='total_bill',data=df,hue='sex')
# Out:
# <Axes: xlabel='time', ylabel='total_bill'>

# %%
sns.boxplot(x='day',y='tip',data=df,hue='sex')
# Out:
# <Axes: xlabel='day', ylabel='tip'>
