# %%
import numpy as np 
import pandas as pd
df=pd.read_csv('chu.csv')
df
# Out:
#        CurrentEquipmentDays  MonthsInService  MonthlyMinutes  \
# 0                     361.0               61           219.0
# 1                    1504.0               58            10.0
# 2                    1812.0               60             8.0
# 3                     458.0               59          1312.0
# 4                     852.0               53             0.0
# ...                     ...              ...             ...
# 49747                 883.0               30            76.0
# 49748                 883.0               30            63.0
# 49749                 882.0               30           724.0
# 49750                 489.0               30           384.0
# 49751                 464.0               29          1745.0
#
#        PercChangeMinutes  TotalRecurringCharge  OffPeakCallsInOut  \
# 0                 -157.0                  22.0               24.0
# 1                   -4.0                  17.0                1.0
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.countplot(x='CurrentEquipmentDays',data=df)
# Out:
# <Axes: xlabel='CurrentEquipmentDays', ylabel='count'>

# %%
sns.boxplot(x='CurrentEquipmentDays',data=df)
# Out:
# <Axes: xlabel='CurrentEquipmentDays'>
